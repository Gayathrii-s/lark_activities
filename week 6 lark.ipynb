# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("Dataset_w6.xlsx")

# %%
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %%
data.isna().sum()
# Out:
# country                                       0
# Region                                        0
# Surface area (km2)                            0
# Population in thousands (2017)                0
# GDP per capita (current US$)                  0
# Agricultural production index                 0
# International trade: Imports (million US$)    0
# dtype: int64

# %% [markdown]
# # Find out how many countries are there in the dataset

# %%
data['country'].count()
# Out:
# 196

# %% [markdown]
# # Examine the data by using visualizations.

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='Region',y='GDP per capita (current US$)',data=data)
plt.title('Boxplot of Region  VS GDP',fontsize=15,fontstyle='oblique',weight='bold')
plt.xlabel('Region',fontsize=15)
plt.ylabel('GDP per capita (current US$)',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='country',y='Population in thousands (2017)',data=data.nlargest(15,'Population in thousands (2017)'))
plt.title('Barplot of country  VS Population',fontsize=25,fontstyle='oblique',weight='bold')
plt.xlabel('country',fontsize=15)
plt.ylabel('Population in thousands (2017)',fontsize=15)
plt.xticks(rotation=90)
plt.grid(linestyle='--')
plt.show()

# %%
data[['GDP per capita (current US$)']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
slice_data=data[['Surface area (km2)','GDP per capita (current US$)','Population in thousands (2017)']]

# %%
sns.heatmap(slice_data.corr(),annot=True)
plt.title('Heatmap')
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5]),
#  [Text(0.5, 0, 'Surface area (km2)'),
#   Text(1.5, 0, 'GDP per capita (current US$)'),
#   Text(2.5, 0, 'Population in thousands (2017)')])

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data)
plt.show()

# %% [markdown]
# # Find out how many countries with respect to the region are available in the dataset

# %%
data[['country','Region']].groupby(['Region']).agg('count')
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# #

# %% [markdown]
# # On average which region has the highest

# %% [markdown]
#  GDP per capita (current US$)

# %%
G=data.groupby('Region')[['GDP per capita (current US$)']].mean()
G
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                          15135.562500
# CentralAmerica                      6348.137500
# CentralAsia                         4329.880000
# EasternAfrica                       2088.852941
# EasternAsia                        27967.614286
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Micronesia                          5008.300000
# MiddleAfrica                        3928.833333
# NorthernAfrica                      3934.960000
# NorthernAmerica                    57659.000000
# NorthernEurope                     42098.220000
# Oceania                            44823.250000
# Polynesia                           8686.520000
# South-easternAsia                  10299.027273
# SouthAmerica                        8499.775000
# SouthernAfrica                      4191.900000
# SouthernAsia                        2968.400000
# ...

# %%
G.nlargest(1,'GDP per capita (current US$)')
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %% [markdown]
# International trade: Imports (million US$)

# %%
I=data.groupby('Region')[['International trade: Imports (million US$)']].mean()
I
# Out:
#                    International trade: Imports (million US$)
# Region
# Caribbean                                         3057.312500
# CentralAmerica                                   57031.500000
# CentralAsia                                      12063.400000
# EasternAfrica                                     4726.176471
# EasternAsia                                     451995.000000
# EasternEurope                                    85243.900000
# Melanesia                                         2896.400000
# Micronesia                                          99.000000
# MiddleAfrica                                      4381.222222
# NorthernAfrica                                   35034.400000
# NorthernAmerica                                 663552.250000
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# Polynesia                                          432.000000
# ...

# %%
I.nlargest(1,'International trade: Imports (million US$)')
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# # Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
data2=data.groupby('Region')['GDP per capita (current US$)','Region'].std()
# Out:
# C:\Users\Gayathri\AppData\Local\Temp/ipykernel_2728/1272487391.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data2=data.groupby('Region')['GDP per capita (current US$)','Region'].std()

# %%
data2.sort_values('GDP per capita (current US$)')
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...

# %%
data2.nsmallest(1,'GDP per capita (current US$)')
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399
